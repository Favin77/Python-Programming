# %% [markdown]
# ## CV Assignment

# %% [markdown]
# ### Program No 2: Implement histogram equalization in Python and apply it to the image

# %%
import cv2 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Original Image")
char=input("Enter Input path address: ")
img=cv2.imread(char,0)
plt.imshow(img)
# Out:
# Original Image
# Enter Input path address: C:\Users\favin\Downloads\Image1.jpg

# %%
img=cv2.imread(char,0)
print("Original Image Histogram")
hist,bins = np.histogram(img.flatten(),256,[0,256])
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('histogram'), loc = 'upper left')
plt.show()
#C:\Users\favin\Downloads\Image1.jpg
# Out:
# Original Image Histogram

# %%
print("Image after Histogram Equalisation")
dst = cv2.equalizeHist(img)#equalize histogram
hist,bins = np.histogram(dst.flatten(),256,[0,256])#no of bins 
plt.hist(dst.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('histogram'), loc = 'upper left')
plt.show()
# Out:
# Image after Histogram Equalisation

# %%
print("Image with Histogram")
dst = cv2.equalizeHist(img)
plt.imshow(dst)#equalize histogram
# Out:
# Image with Histogram
